# %%
from transformers import AutoModelForSeq2SeqLM, AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained("facebook/nllb-200-distilled-600M")
model = AutoModelForSeq2SeqLM.from_pretrained("facebook/nllb-200-distilled-600M")

article = "UN Chief says there is no military solution in Syria"
inputs = tokenizer(article, return_tensors="pt")

translated_tokens = model.generate(
    **inputs, forced_bos_token_id=tokenizer.convert_tokens_to_ids("tel_Telu"), max_length=30
)
tokenizer.batch_decode(translated_tokens, skip_special_tokens=True)[0]
# Out:
# 'సిరియాలో సైనిక పరిష్కారం లేదని ఐక్యరాజ్యసమితి చీఫ్ చెప్పారు'

# %%
article = "Enter Superj"
inputs = tokenizer(article, return_tensors="pt")

translated_tokens = model.generate(
    **inputs, forced_bos_token_id=tokenizer.convert_tokens_to_ids("tam_Taml"), max_length=30
)
tokenizer.batch_decode(translated_tokens, skip_special_tokens=True)[0]
# Out:
# 'Superj ஐ உள்ளிடவும்'

# %%
import torch
from transformers import AutoModelForSeq2SeqLM, AutoTokenizer
import time
# from flash_attn import flash_attn_func
model = AutoModelForSeq2SeqLM.from_pretrained("facebook/nllb-200-distilled-600M", torch_dtype=torch.bfloat16).to("cuda").eval()
tokenizer = AutoTokenizer.from_pretrained("facebook/nllb-200-distilled-600M")
start = time.time()
article = "Enter Superj"
inputs = tokenizer(article, return_tensors="pt").to("cuda")

translated_tokens = model.generate(
    **inputs, forced_bos_token_id=tokenizer.convert_tokens_to_ids("tam_Taml"), max_length=30
)
tokenizer.batch_decode(translated_tokens, skip_special_tokens=True)[0]
print(time.time()-start)
# Out:
# 0.6081926822662354

# %%
import torch
from transformers import AutoModelForSeq2SeqLM, AutoTokenizer
import time

model = AutoModelForSeq2SeqLM.from_pretrained("facebook/nllb-200-distilled-1.3B", torch_dtype=torch.bfloat16).to("cuda").eval()
tokenizer = AutoTokenizer.from_pretrained("facebook/nllb-200-distilled-1.3B")
# Out:
# config.json:   0%|          | 0.00/808 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/5.48G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/189 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/564 [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/4.85M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.3M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/3.55k [00:00<?, ?B/s]

# %%
start = time.time()
article = """They know he was a great president and we want to make him president again."""
inputs = tokenizer(article, return_tensors="pt").to("cuda")

translated_tokens = model.generate(
    **inputs, forced_bos_token_id=tokenizer.convert_tokens_to_ids("tam_Taml")
)
data = tokenizer.batch_decode(translated_tokens, skip_special_tokens=True)[0]
print(data)
print(time.time()-start)
# Out:
# அவர் ஒரு சிறந்த ஜனாதிபதி என்று அவர்கள் அறிவார்கள் நாம் அவரை மீண்டும் ஜனாதிபதி செய்ய வேண்டும்.
# 0.2944204807281494

# %%
start = time.time()
article = """They know he was a great president and we want to make him president again."""
inputs = tokenizer(article, return_tensors="pt").to("cuda")

translated_tokens = model.generate(
    **inputs, forced_bos_token_id=tokenizer.convert_tokens_to_ids("tel_Telu"), max_length=1024
)
data = tokenizer.batch_decode(translated_tokens, skip_special_tokens=True)[0]
print(data)
print(time.time()-start)
# Out:
# వారు అతను ఒక గొప్ప అధ్యక్షుడు అని తెలుసు మరియు మేము మళ్ళీ అధ్యక్షుడు చేయడానికి కోరుకుంటున్నారో.
# 0.32362914085388184

# %%
start = time.time()
article = """They know he was a great president and we want to make him president again."""
inputs = tokenizer(article, return_tensors="pt").to("cuda")

translated_tokens = model.generate(
    **inputs, forced_bos_token_id=tokenizer.convert_tokens_to_ids("tel_Telu"), max_length=1024
)
data = tokenizer.batch_decode(translated_tokens, skip_special_tokens=True)[0]
print(data)
print(time.time()-start)
# Out:
# ఆయన గొప్ప అధ్యక్షుడని వారికి తెలుసు. ఆయనను మళ్లీ అధ్యక్షుడిగా చేయాలనుకుంటున్నాం.
# 0.7120928764343262
